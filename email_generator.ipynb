# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(
    temperature=0, 
    groq_api_key='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',  
    model_name="llama-3.3-70b-versatile"
)
response = llm.invoke("The first person to land on moon was ...")
print(response.content)
# Out:
# The first person to land on the moon was Neil Armstrong. He stepped out of the lunar module Eagle and onto the moon's surface on July 20, 1969, during the Apollo 11 mission. Armstrong famously declared, "That's one small step for man, one giant leap for mankind," as he became the first human to set foot on the moon.

# %%
from langchain_community.document_loaders import WebBaseLoader
from langchain_core.prompts import PromptTemplate

# FIX 1: URL must be in a list
loader = WebBaseLoader(["https://jobs.citi.com/job/pune/lead-data-analytics-and-reporting/287/89366902880"])

# FIX 2: BeautifulSoup must be installed
page = loader.load()[0].page_content

print(page)
# Out:
# Lead Data Analytics and Reporting | Citi Careers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to main content
#
#
#
#
# Menu
#
#
#
#
#
# Careers
#
#
# Search Jobs
#
#
#
#
#
#
# Saved Jobs
#
#
#
#
#
#
#
#
# Search Jobs
#
#
# Why Citi
#
#
#
# About Us
#
#
# People, Engagement and Inclusion
#
#
#
#
#
# Early Careers
#
#
#
# Early Careers Overview
#
#
# Job Simulations
#
#
# Events
#
#
#
#
#
# Talent Networks
#
#
#
# Early Careers Talent Network (opens in new window)
#
#
# Career Professionals Talent Network (opens in new window)
#
#
#
#
#
#
#
# Saved Jobs
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Join Our Team
#
#
#
#
#
#
#
# Lead Data Analytics and Reporting
#
# Apply (opens in new window)
# Save
#
#
#
#
# Job Req Id:
# 25925442
#
#
# Location(s):
# Pune, Maharashtra, India, Chennai, Tamil Nadu, India
#
#
# ...

# %%
prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the 
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):    
        """
)

chain_extract = prompt_extract | llm 
# use the already-loaded `page` variable (from previous cell) instead of undefined `page_data`
res = chain_extract.invoke({"page_data": page})
type(res.content)
# Out:
# str

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# [{'role': 'Lead Data Analytics and Reporting',
#   'experience': '10 + years',
#   'skills': ['SQL',
#    'Python',
#    'Tableau',
#    'Data Governance',
#    'Data Management',
#    'Data Quality',
#    'Internal Controls',
#    'Management Reporting',
#    'Policy and Procedure',
#    'Program Management',
#    'Risk Controls and Monitors',
#    'Risk Management'],
#   'description': 'The Data Governance Foundation Lead Analyst is responsible for contributing to the directional strategy and assisting in creation and modification of Enterprise Data Governance Strategy, and/or Data Risk and Control Framework and Data Risk Taxonomy.'},
#  {'role': 'Senior AML Compliance Analyst',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': 'Public Cloud Engineer Vice President',
#   'experience': None,
#   'skills': None,
#   'description': None},
#  {'role': 'Personal Banker SAFE Act, Mission Viejo Branch, Officer',
#   'experience': None,
#   'skills': None,
# ...

# %%
type(json_res)
# Out:
# list

# %%
# %pip install pandas
import pandas as pd

df = pd.read_csv("my_portfolio.csv")
df
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ------------ --------------------------- 3.4/11.0 MB 21.2 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 30.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 29.2 MB/s  0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
#
#    ---------------------------------------- 0/3 [pytz]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
# ...

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])

# %%
job = json_res[0]
links = collection.query(query_texts=job['skills'], n_results=2).get('metadatas', [])
links
# Out:
# [[{'links': 'https://example.com/magento-portfolio'},
#   {'links': 'https://example.com/wordpress-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/python-portfolio'}],
#  [{'links': 'https://example.com/flutter-portfolio'},
#   {'links': 'https://example.com/android-tv-portfolio'}],
#  [{'links': 'https://example.com/ios-portfolio'},
#   {'links': 'https://example.com/flutter-portfolio'}],
#  [{'links': 'https://example.com/magento-portfolio'},
#   {'links': 'https://example.com/wordpress-portfolio'}],
#  [{'links': 'https://example.com/ios-portfolio'},
#   {'links': 'https://example.com/magento-portfolio'}],
#  [{'links': 'https://example.com/full-stack-js-portfolio'},
#   {'links': 'https://example.com/typescript-frontend-portfolio'}],
#  [{'links': 'https://example.com/angular-portfolio'},
#   {'links': 'https://example.com/java-portfolio'}],
#  [{'links': 'https://example.com/java-portfolio'},
# ...

# %%
job
# Out:
# {'role': 'Lead Data Analytics and Reporting',
#  'experience': '10 + years',
#  'skills': ['SQL',
#   'Python',
#   'Tableau',
#   'Data Governance',
#   'Data Management',
#   'Data Quality',
#   'Internal Controls',
#   'Management Reporting',
#   'Policy and Procedure',
#   'Program Management',
#   'Risk Controls and Monitors',
#   'Risk Management'],
#  'description': 'The Data Governance Foundation Lead Analyst is responsible for contributing to the directional strategy and assisting in creation and modification of Enterprise Data Governance Strategy, and/or Data Risk and Control Framework and Data Risk Taxonomy.'}

# %%
# select the first job from the parsed JSON list and access its skills
job = json_res[0]
job['skills']
# Out:
# ['SQL',
#  'Python',
#  'Tableau',
#  'Data Governance',
#  'Data Management',
#  'Data Quality',
#  'Internal Controls',
#  'Management Reporting',
#  'Policy and Procedure',
#  'Program Management',
#  'Risk Controls and Monitors',
#  'Risk Management']

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}
        
        ### INSTRUCTION:
        You are Mohan, a business development executive at AtliQ. AtliQ is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools. 
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability, 
        process optimization, cost reduction, and heightened overall efficiency. 
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of AtliQ 
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase Atliq's portfolio: {link_list}
        Remember you are Mohan, BDE at AtliQ. 
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):
        
        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Expert Data Analytics and Reporting Solutions for Your Business
#
# Dear Hiring Manager,
#
# I came across the job description for the Lead Data Analytics and Reporting role, and I was impressed by the scope of responsibilities and the skills required. As a Business Development Executive at AtliQ, I believe our company can provide the necessary expertise to support your data analytics and reporting needs.
#
# At AtliQ, we have a proven track record of delivering tailored solutions that foster scalability, process optimization, cost reduction, and heightened overall efficiency. Our team of experts has extensive experience in working with various technologies, including SQL, Python, and Tableau, which are essential for data analytics and reporting.
#
# We have successfully empowered numerous enterprises with our data management and governance solutions, ensuring data quality, internal controls, and risk management. Our portfolio includes projects such as:
#
# ...
