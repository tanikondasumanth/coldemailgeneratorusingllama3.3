# %%
# %pip install langchain
# Out:
# Requirement already satisfied: langchain in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (1.1.3)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.2 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langchain) (1.1.3)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langchain) (1.0.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain) (0.4.59)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.2->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.15)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.2->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.2->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.2->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.12.0)
# Requirement already satisfied: certifi in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.2->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.2->langchain) (2.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install langchain-groq
# Out:
# Requirement already satisfied: langchain-groq in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (1.1.0)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langchain-groq) (0.37.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langchain-groq) (1.1.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (2.12.5)
# Requirement already satisfied: sniffio in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain-groq) (3.11)
# Requirement already satisfied: certifi in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (0.4.59)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langchain-core<2.0.0,>=1.1.0->langchain-groq) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.0->langchain-groq) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tsuma\downloads\project-genai-cold-email-generator-main\project-genai-cold-email-generator-main\.venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.0->langchain-groq) (2.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -qU langchain-groq
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    temperature=0, 
    groq_api_key='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', 
    model_name="llama-3.3-70b-versatile"
)

response = llm.invoke("first person to land on moon was ...")
print(response.content)
# Out:
# The first person to land on the Moon was Neil Armstrong. He stepped out of the lunar module Eagle and onto the Moon's surface on July 20, 1969, during the Apollo 11 mission. Armstrong famously declared, "That's one small step for man, one giant leap for mankind," as he became the first human to set foot on the Moon.
